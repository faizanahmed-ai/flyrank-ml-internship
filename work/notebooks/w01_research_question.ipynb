# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/faizanahmed-ai/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# I'm choosing **Refresh / Content Opportunity Scoring** because I've already validated this workflow during my FlyRank internship. I compared a hand-crafted scoring rule with a Random Forest model on SEO traffic data and found that the learned model performed better. This project builds directly on that foundation by applying the same approach to a larger warehouse dataset with more rigorous validation.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# The decision is to identify which pages should be reviewed first. The recommended action is to refresh, expand, protect, prune, or monitor each page. A wrong recommendation wastes valuable review time or misses pages with significant traffic potential. Machine learning strengthens this process by learning complex patterns across multiple signals, delivering more accurate recommendations than fixed rules.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\BCC\Desktop\flyrank-ml-internship\data\raw\content_refresh_anonymized.csv")
print("Rows:", len(df))
print("Declining pages:", (df['trend_direction'] == 'down').sum())
print("Average impressions (90d):", df['impressions_90d'].mean())
# Out:
# Rows: 30000
# Declining pages: 16262
# Average impressions (90d): 5200.3663

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# **Can claim:** This model outperforms a fixed rule at ranking review candidates on this data. That's decision-support it tells reviewers where to look first, not what will happen.
#
# **Cannot claim:** Refreshing a page will recover traffic. Correlation isn't causation proving that takes a real experiment, not this analysis. This also says nothing about how Google's algorithm actually works.
#
# **Data boundary:** Built only on observable signals  impressions, clicks, position, freshness. FlyRank's internal health_score and priority_score never touch this model.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
